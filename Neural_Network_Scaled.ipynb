# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
diamond_df = pd.read_csv("./Resources/scaled.csv")
diamond_df.head()
# Out:
#    Unnamed: 0     carat     depth     table     price  cut_b'Fair'  \
# 0           0 -1.405572 -0.156729 -1.120720 -1.038223    -0.197533
# 1           1 -1.447307 -1.265593  1.490024 -1.038223    -0.197533
# 2           2 -1.405572 -3.157185  3.230521 -1.037985    -0.197533
# 3           3 -1.280367  0.430317  0.184652 -1.036319    -0.197533
# 4           4 -1.238632  1.017363  0.184652 -1.036081    -0.197533
#
#    cut_b'Good'  cut_b'Ideal'  cut_b'Premium'  cut_b'Very Good'  ...  \
# 0    -0.342592      1.305138       -0.566777         -0.568675  ...
# 1    -0.342592     -0.766202        1.764362         -0.568675  ...
# 2     2.918924     -0.766202       -0.566777         -0.568675  ...
# 3    -0.342592     -0.766202        1.764362         -0.568675  ...
# 4     2.918924     -0.766202       -0.566777         -0.568675  ...
#
#    color_b'I'  color_b'J'  clarity_b'I1'  clarity_b'IF'  clarity_b'SI1'  \
# 0   -0.359811   -0.263711      -0.134557      -0.172747       -0.574252
# 1   -0.359811   -0.263711      -0.134557      -0.172747        1.741395
# 2   -0.359811   -0.263711      -0.134557      -0.172747       -0.574252
# 3    2.779237   -0.263711      -0.134557      -0.172747       -0.574252
# 4   -0.359811    3.792031      -0.134557      -0.172747       -0.574252
#
#    clarity_b'SI2'  clarity_b'VS1'  clarity_b'VS2'  clarity_b'VVS1'  \
# 0        2.004444       -0.421931       -0.510935        -0.254255
# 1       -0.498891       -0.421931       -0.510935        -0.254255
# 2       -0.498891        2.370058       -0.510935        -0.254255
# 3       -0.498891       -0.421931        1.957197        -0.254255
# 4        2.004444       -0.421931       -0.510935        -0.254255
#
#    clarity_b'VVS2'
# 0        -0.308898
# 1        -0.308898
# 2        -0.308898
# 3        -0.308898
# 4        -0.308898
#
# [5 rows x 25 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = diamond_df['price'].values
y

X = diamond_df.drop('price', axis=1).values
X

# Split the preprocessed data into a training and testing dataset
X_train, X_test,y_train,y_test =train_test_split(X,y, random_state=10)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

diamonds_nn= len(X_train_scaled[5])
hidden_node_layer = 10
second_hidden_node_layer =100
third_hidden_layer= 150
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_node_layer, input_dim=diamonds_nn, activation='relu'))
#additional layer
nn.add(tf.keras.layers.Dense(units=third_hidden_layer, input_dim=diamonds_nn, activation='relu'))
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=second_hidden_node_layer, activation='relu'))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='linear'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 10)                250
#
#  dense_17 (Dense)            (None, 150)               1650
#
#  dense_18 (Dense)            (None, 100)               15100
#
#  dense_19 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 17,101
# Trainable params: 17,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
nn.compile(optimizer='adam',loss='mean_squared_error', metrics=['mean_squared_error'])

# %%
# Train the model
trained_model = nn.fit(X_train_scaled, y_train, epochs=10)
# Out:
# Epoch 1/10
# 932/932 [==============================] - 4s 3ms/step - loss: 0.1642 - mean_squared_error: 0.1642
# Epoch 2/10
# 932/932 [==============================] - 3s 3ms/step - loss: 0.0371 - mean_squared_error: 0.0371
# Epoch 3/10
# 932/932 [==============================] - 3s 3ms/step - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 4/10
# 932/932 [==============================] - 4s 5ms/step - loss: 0.0232 - mean_squared_error: 0.0232
# Epoch 5/10
# 932/932 [==============================] - 3s 4ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 6/10
# 932/932 [==============================] - 4s 4ms/step - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 7/10
# 932/932 [==============================] - 3s 3ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 8/10
# 932/932 [==============================] - 4s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 9/10
# 932/932 [==============================] - 3s 3ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 10/10
# 932/932 [==============================] - 3s 3ms/step - loss: 0.0033 - mean_squared_error: 0.0033

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Mean Squared Error: {model_accuracy}")
# Out:
# 311/311 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - 427ms/epoch - 1ms/step
# Loss: 0.002836615312844515, Mean Squared Error: 0.002836615312844515
